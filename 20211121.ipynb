# %% [markdown]
# <a href="https://colab.research.google.com/github/DaheeJang/class2021fall/blob/main/20211121.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import IPython.display as ipd

# %%
def phasor_sine(amp, sr, dur, freq, phase) :
  t = np.arange(1, sr+dur+1)/sr
  theta = t* 2*np.pi * freq + phase
  s = amp * np.sin(theta)
  return s, t, theta

# %%
amp = 1; sr = 10000; dur = 1; freq = 440; phase = 0
s, t, theta = phasor_sine(amp, sr, dur, freq, phase)
ipd.Audio(s, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
amp = 1; sr = 10000

G  = 783.99 
A  = 880.00
E  = 659.25
F  = 698.46 
C  = 1046.50
B  = 987.76

empty = np.empty(0)

tmp, t, theta= phasor_sine(amp, sr, 0.25, G, phase)
all = np.concatenate((empty, tmp))

tmp, t, theta = phasor_sine(amp, sr, 0.5, A, phase)
all = np.concatenate((all, tmp))

tmp, t, theta = phasor_sine(amp, sr, 0.25, G, phase)
all = np.concatenate((all, tmp))

tmp, t, theta = phasor_sine(amp, sr, 1, E, phase)
all = np.concatenate((all, tmp))

tmp, t, theta = phasor_sine(amp, sr, 1, C, phase)
all = np.concatenate((all, tmp))

tmp, t, theta = phasor_sine(amp, sr, 1, A, phase)
all = np.concatenate((all, tmp))

tmp, t, theta = phasor_sine(amp, sr, 0.5, G, phase)
all = np.concatenate((all, tmp))

tmp, t, theta = phasor_sine(amp, sr, 0.5, G, phase)
all = np.concatenate((all, tmp*0))

tmp, t, theta = phasor_sine(amp, sr, 0.25, G, phase)
all = np.concatenate((all, tmp))

tmp, t, theta = phasor_sine(amp, sr, 0.25, A, phase)
all = np.concatenate((all, tmp))

tmp, t, theta = phasor_sine(amp, sr, 0.25, G, phase)
all = np.concatenate((all, tmp))

tmp, t, theta = phasor_sine(amp, sr, 0.25, A, phase)
all = np.concatenate((all, tmp))

tmp, t, theta = phasor_sine(amp, sr, 0.5, G, phase)
all = np.concatenate((all, tmp))

tmp, t, theta = phasor_sine(amp, sr, 0.5, C, phase)
all = np.concatenate((all, tmp))

tmp, t, theta = phasor_sine(amp, sr, 1, B, phase)
all = np.concatenate((all, tmp))

# %%
#루돌프사슴코
ipd.Audio(all, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# 속도를 조절하는 방법을 잘 모르겠습니다. 중간에 곡 이름을 붙였더니 갑자기 분량이 4초로 줄어들면서 피치가 올라갔는데, 수정하니 다시 15초 분량이 되었습니다 ㅠㅠ 어떻게 해결하면 될지 궁금합니다!
